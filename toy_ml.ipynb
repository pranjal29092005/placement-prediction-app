# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df= df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3)

# %%
X_train
# Out:
#     cgpa     iq
# 73   4.9   61.0
# 17   3.3  183.0
# 11   6.9  138.0
# 92   5.2  110.0
# 31   3.9  109.0
# ..   ...    ...
# 20   6.6  120.0
# 63   6.3  128.0
# 81   5.4  107.0
# 62   6.0  102.0
# 33   6.0  149.0
#
# [70 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 80   4.9  196.0
# 50   3.5  233.0
# 78   6.1   81.0
# 95   4.3  200.0
# 9    5.1   66.0
# 42   7.6   89.0
# 48   6.6  138.0
# 45   6.0   66.0
# 82   6.5   37.0
# 26   7.0  199.0
# 16   5.2  224.0
# 29   7.0  112.0
# 10   6.0   45.0
# 25   5.0   91.0
# 47   5.2  161.0
# 74   6.7  154.0
# 65   8.1  166.0
# 64   7.0   64.0
# 88   4.4  149.0
# 38   6.5  160.0
# 18   4.0  100.0
# 85   5.8  166.0
# 46   5.3  114.0
# 69   8.5  120.0
# 55   7.8  114.0
# 61   7.3  137.0
# 86   5.1  128.0
# 28   5.2   90.0
# 12   5.4  139.0
# 71   6.1  132.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-9.99115084e-01, -1.77981912e+00],
#        [-2.45426319e+00,  1.82455728e+00],
#        [ 8.19820050e-01,  4.95074182e-01],
#        [-7.26274814e-01, -3.32159746e-01],
#        [-1.90858265e+00, -3.61703814e-01],
#        [ 4.56033023e-01, -9.23041123e-01],
#        [-2.71541031e-01,  6.42794527e-01],
#        [-1.81763589e+00, -1.36620216e+00],
#        [ 4.56033023e-01,  2.58721632e-01],
#        [-1.09006184e+00,  1.23367590e+00],
#        [ 1.27455383e+00,  3.17809769e-01],
#        [ 1.00171356e+00,  8.79147078e-01],
#        [-1.09006184e+00, -2.73071608e-01],
#        [ 8.19820050e-01,  5.24618251e-01],
#        [-1.45384887e+00, -2.34115643e+00],
#        [ 1.36550059e+00, -1.77981912e+00],
#        [ 1.36550059e+00,  1.08595556e+00],
#        [-2.71541031e-01,  5.54162320e-01],
#        [-1.18100860e+00, -2.04571574e+00],
#        [-9.99115084e-01,  9.97323353e-01],
#        [-7.26274814e-01,  3.17809769e-01],
#        [ 1.18360708e+00, -1.54895332e-01],
#        [ 9.10766806e-01,  1.58820473e+00],
#        [ 2.74139510e-01, -5.38968228e-01],
#        [ 6.37926536e-01,  1.79501321e+00],
#        [-1.09006184e+00,  5.83706389e-01],
#        [ 7.28873293e-01, -9.23041123e-01],
#        [ 1.18360708e+00, -2.10480388e+00],
#        [ 1.18360708e+00, -1.04121740e+00],
#        [-1.09006184e+00,  1.41094032e+00],
#        [ 1.45644735e+00,  1.99633494e-01],
#        [ 7.28873293e-01, -2.73071608e-01],
#        [-1.18100860e+00, -1.01167333e+00],
#        [ 1.91118113e+00,  8.20058940e-01],
#        [ 1.83192753e-01, -2.43527539e-01],
#        [-1.27195535e+00,  7.31426733e-01],
#        [-1.18100860e+00, -7.17498815e-03],
#        [-9.08168328e-01, -9.58071947e-02],
#        [ 9.22459961e-02,  1.02686742e+00],
#        [ 9.22459961e-02, -1.66164284e+00],
#        [ 8.19820050e-01, -7.45776710e-01],
#        [ 3.65086266e-01,  5.83706389e-01],
#        [ 2.09307464e+00,  1.38139625e+00],
#        [-5.44381301e-01,  4.06441976e-01],
#        [ 1.82023437e+00, -1.24802588e+00],
#        [ 1.29923938e-03,  8.14572184e-02],
#        [ 1.36550059e+00,  2.58721632e-01],
#        [-2.71541031e-01,  3.17809769e-01],
#        [-9.99115084e-01,  8.79147078e-01],
#        [-6.35328058e-01, -7.17498815e-03],
#        [-9.99115084e-01, -3.67190570e-02],
#        [ 7.28873293e-01,  5.19131496e-02],
#        [-1.80594274e-01,  6.13250458e-01],
#        [ 9.22459961e-02, -5.38968228e-01],
#        [-9.99115084e-01,  3.76897907e-01],
#        [ 2.74139510e-01,  1.70089425e-01],
#        [ 1.00171356e+00, -2.16389201e+00],
#        [ 7.28873293e-01,  5.83706389e-01],
#        [-2.71541031e-01,  1.41094032e+00],
#        [-9.08168328e-01, -1.72073098e+00],
#        [ 3.65086266e-01, -1.54895332e-01],
#        [-8.96475173e-02, -4.50336021e-01],
#        [-5.44381301e-01, -2.13983470e-01],
#        [-8.17221571e-01,  1.61774880e+00],
#        [ 9.10766806e-01,  5.24618251e-01],
#        [ 5.46979780e-01, -3.67190570e-02],
#        [ 2.74139510e-01,  1.99633494e-01],
#        [-5.44381301e-01, -4.20791952e-01],
#        [ 1.29923938e-03, -5.68512296e-01],
#        [ 1.29923938e-03,  8.20058940e-01]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-9.99115084e-01,  2.20863018e+00],
#        [-2.27236968e+00,  3.30176072e+00],
#        [ 9.22459961e-02, -1.18893774e+00],
#        [-1.54479562e+00,  2.32680645e+00],
#        [-8.17221571e-01, -1.63209878e+00],
#        [ 1.45644735e+00, -9.52585192e-01],
#        [ 5.46979780e-01,  4.95074182e-01],
#        [ 1.29923938e-03, -1.63209878e+00],
#        [ 4.56033023e-01, -2.48887677e+00],
#        [ 9.10766806e-01,  2.29726238e+00],
#        [-7.26274814e-01,  3.03586410e+00],
#        [ 9.10766806e-01, -2.73071608e-01],
#        [ 1.29923938e-03, -2.25252422e+00],
#        [-9.08168328e-01, -8.93497054e-01],
#        [-7.26274814e-01,  1.17458777e+00],
#        [ 6.37926536e-01,  9.67779284e-01],
#        [ 1.91118113e+00,  1.32230811e+00],
#        [ 9.10766806e-01, -1.69118691e+00],
#        [-1.45384887e+00,  8.20058940e-01],
#        [ 4.56033023e-01,  1.14504370e+00],
#        [-1.81763589e+00, -6.27600434e-01],
#        [-1.80594274e-01,  1.32230811e+00],
#        [-6.35328058e-01, -2.13983470e-01],
#        [ 2.27496816e+00, -3.67190570e-02],
#        [ 1.63834086e+00, -2.13983470e-01],
#        [ 1.18360708e+00,  4.65530114e-01],
#        [-8.17221571e-01,  1.99633494e-01],
#        [-7.26274814e-01, -9.23041123e-01],
#        [-5.44381301e-01,  5.24618251e-01],
#        [ 9.22459961e-02,  3.17809769e-01]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(class_weight='balanced')

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 80    0
# 50    0
# 78    0
# 95    0
# 9     0
# 42    1
# 48    1
# 45    1
# 82    1
# 26    1
# 16    0
# 29    1
# 10    1
# 25    0
# 47    0
# 74    1
# 65    1
# 64    1
# 88    0
# 38    1
# 18    0
# 85    1
# 46    0
# 69    1
# 55    1
# 61    1
# 86    0
# 28    0
# 12    0
# 71    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = clf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[13  1]
#  [ 3 13]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87        14
#            1       0.93      0.81      0.87        16
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.87      0.87        30
# weighted avg       0.87      0.87      0.87        30

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8666666666666667

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,y_train.values,clf= clf,legend = 2)
# Out:
# <Axes: >
